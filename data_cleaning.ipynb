# %%
import pandas as pd
# download the csv file from here: https://www.google.com/covid19/mobility/index.html?hl=en
df = pd.read_csv('Global_Mobility_Report.csv')
# Out:
# C:\Users\haomi\miniconda3\envs\stat451\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df = df.loc[df['country_region']=="United States"]
# Drop the columns that we will not use for the analysis
df = df.drop(columns=['country_region_code','iso_3166_2_code', 'census_fips_code',"metro_area","country_region"])
# Rename the rest of the columns for easier accessing
df = df.rename(columns={'sub_region_1': 'state',
                        'sub_region_2': 'county',
                        'retail_and_recreation_percent_change_from_baseline': 'retail',
                        'grocery_and_pharmacy_percent_change_from_baseline': 'grocery',
                        'parks_percent_change_from_baseline': 'parks',
                        'transit_stations_percent_change_from_baseline': 'transit',
                        'workplaces_percent_change_from_baseline': 'workplaces',
                        'residential_percent_change_from_baseline': 'residential'})
df.sample(10)
# Out:
#                  state            county        date  retail  grocery  parks  \
# 2177374       Michigan     Antrim County  2020-07-09     NaN      NaN    NaN
# 2451576          Texas     Wilson County  2020-02-25     5.0      7.0    NaN
# 1978818       Arkansas       Yell County  2020-02-27    14.0      4.0    NaN
# 2014313        Florida     Nassau County  2020-03-02    11.0     14.0   21.0
# 2069937       Illinois   Marshall County  2020-03-12     NaN      NaN    NaN
# 2215028    Mississippi  Humphreys County  2020-06-04     NaN      NaN    NaN
# 2124158         Kansas   Marshall County  2020-03-30   -28.0      NaN    NaN
# 2499686  West Virginia    Kanawha County  2020-03-05    14.0      7.0   10.0
# 2497553  West Virginia     Brooke County  2020-08-28     NaN      NaN    NaN
# 2514850      Wisconsin     Oneida County  2020-04-21   -35.0     -9.0    NaN
#
#          transit  workplaces  residential
# 2177374      NaN       -19.0          NaN
# 2451576      NaN         1.0          0.0
# 1978818      NaN         1.0          NaN
# 2014313      6.0         4.0         -1.0
# 2069937      NaN         1.0          NaN
# 2215028      NaN       -19.0          NaN
# 2124158      NaN       -23.0          NaN
# 2499686     10.0         2.0         -1.0
# 2497553      NaN       -28.0          NaN
# 2514850      NaN       -36.0         15.0

# %%
df = df[(df["state"] == "Wisconsin") & (df["county"].notnull())]
df.sample(10)
# Out:
#              state              county        date  retail  grocery  parks  \
# 2507031  Wisconsin        Brown County  2020-05-20   -19.0     10.0  197.0
# 2509056  Wisconsin         Door County  2020-02-19     5.0    -15.0    NaN
# 2515707  Wisconsin       Pierce County  2020-05-29    -1.0      NaN    NaN
# 2514370  Wisconsin       Monroe County  2020-03-12    19.0     15.0    NaN
# 2518588  Wisconsin  Trempealeau County  2020-03-02     6.0      0.0    NaN
# 2509797  Wisconsin   Eau Claire County  2020-05-10   -36.0     -4.0    NaN
# 2513600  Wisconsin     Marathon County  2020-06-30     2.0     16.0    NaN
# 2509403  Wisconsin      Douglas County  2020-06-25    12.0     12.0    NaN
# 2519938  Wisconsin     Waukesha County  2020-05-13   -32.0     -5.0  129.0
# 2508464  Wisconsin     Crawford County  2020-04-05   -33.0      3.0    NaN
#
#          transit  workplaces  residential
# 2507031    -70.0       -38.0         13.0
# 2509056      NaN         3.0          NaN
# 2515707      NaN       -34.0         13.0
# 2514370      3.0        -1.0          0.0
# 2518588      NaN         4.0         -1.0
# 2509797      NaN       -25.0          7.0
# 2513600      NaN       -28.0          7.0
# 2509403      NaN       -26.0          5.0
# 2519938    -18.0       -46.0         20.0
# 2508464      NaN       -20.0          NaN

# %%
df.to_csv('WI_Mobility_Report.csv', index=False)

# %%
covid = pd.read_csv("covid-us-counties.csv")
covid.sample(10)
# Out:
#               date       county       state     fips  cases  deaths
# 288741  2020-06-30         Burt    Nebraska  31021.0     14       0
# 251195  2020-06-18       Bergen  New Jersey  34003.0  18949    1684
# 237407  2020-06-14     Seminole     Florida  12117.0    759      13
# 159653  2020-05-19       McMinn   Tennessee  47107.0    125      12
# 75171   2020-04-20        Crane       Texas  48103.0      2       0
# 189092  2020-05-29        Adair    Missouri  29001.0     50       0
# 470598  2020-08-26  Buena Vista        Iowa  19021.0   1822      12
# 30414   2020-04-03     Maverick       Texas  48323.0      4       0
# 45797   2020-04-10      Autauga     Alabama   1001.0     17       1
# 113048  2020-05-04    Champaign    Illinois  17019.0    182       6

# %%
covid = covid[covid["state"] == "Wisconsin"]
covid.sample(10)
# Out:
#               date     county      state     fips  cases  deaths
# 184542  2020-05-27  Outagamie  Wisconsin  55087.0    198       8
# 557101  2020-09-21  Sheboygan  Wisconsin  55117.0   1506      15
# 133195  2020-05-10       Sauk  Wisconsin  55111.0     71       3
# 402032  2020-08-04   Richland  Wisconsin  55103.0     32       4
# 84019   2020-04-23   Walworth  Wisconsin  55127.0    100       7
# 550606  2020-09-19  Menominee  Wisconsin  55078.0     43       0
# 28363   2020-04-02     Pierce  Wisconsin  55093.0      7       0
# 187612  2020-05-28    Shawano  Wisconsin  55115.0     43       0
# 100991  2020-04-29   Waushara  Wisconsin  55137.0      2       0
# 218330  2020-06-07      Adams  Wisconsin  55001.0      5       1

# %%
covid.to_csv('covid_cases.csv', index=False)
